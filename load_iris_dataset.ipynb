# %%
from sklearn import datasets

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
iris = datasets.load_iris()

# %%
x = iris.data
y = iris.target

# %%
for i in range(150):
  print(f"data: {x[i]} and prediction: {y[i]} and names: {iris.target_names[y[i]]}")
# Out:
# data: [5.1 3.5 1.4 0.2] and prediction: 0 and names: setosa
# data: [4.9 3.  1.4 0.2] and prediction: 0 and names: setosa
# data: [4.7 3.2 1.3 0.2] and prediction: 0 and names: setosa
# data: [4.6 3.1 1.5 0.2] and prediction: 0 and names: setosa
# data: [5.  3.6 1.4 0.2] and prediction: 0 and names: setosa
# data: [5.4 3.9 1.7 0.4] and prediction: 0 and names: setosa
# data: [4.6 3.4 1.4 0.3] and prediction: 0 and names: setosa
# data: [5.  3.4 1.5 0.2] and prediction: 0 and names: setosa
# data: [4.4 2.9 1.4 0.2] and prediction: 0 and names: setosa
# data: [4.9 3.1 1.5 0.1] and prediction: 0 and names: setosa
# data: [5.4 3.7 1.5 0.2] and prediction: 0 and names: setosa
# data: [4.8 3.4 1.6 0.2] and prediction: 0 and names: setosa
# data: [4.8 3.  1.4 0.1] and prediction: 0 and names: setosa
# data: [4.3 3.  1.1 0.1] and prediction: 0 and names: setosa
# data: [5.8 4.  1.2 0.2] and prediction: 0 and names: setosa
# data: [5.7 4.4 1.5 0.4] and prediction: 0 and names: setosa
# ...
